# %%
a = {
  "pInfo": [
    {
      "imgUrl": "http://localhost/resources/persona/curation/230502/2305021740.jpg",
      "selInfo": "10대남성,20대남성",
      "img_id": "C02",
      "img_info": "F",
      "type": "of"
    }
  ]
}

# %%
a['pInfo'][0]['img_info']
# Out:
# 'F'

# %%
person = ['person']

elec = ['cell phone', 'laptop', 'mouse', 'remote', 'keyboard',  'hair drier', 'toothbrush']

home = ['tv', 'microwave', 'oven', 'toaster', 'refrigerator', 'sink']

fur = ['chair', 'couch', 'bed', 'dining table', 'toilet']

mot = ['bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat']

inter = ['frisbee', 'kite', 'skis', 'snowboard', 'surfboard', 'tennis racket', 'potted plant', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'baseball bat', 'baseball glove', 'skateboard','sports ball', 'clock', 'vase', 'scissors', 'teddy bear', 'book']

dish = ['bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl']

etc = ['fire hydrant', 'stop sign', 'traffic light', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake']

# %%
import pandas as pd
# 인덱스를 지정해 시트 설정




df = pd.read_excel('sheet1.xlsx')

# %%
df.columns
# Out:
# Index(['ID / 사진명', '구분', '연령', 'off/on', '연령.1', '성별', 'type', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', '2023 일반소비성향 키워드', '일반적 소비 성향', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', '소비(구매) 결정 영향 요인', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', '소비력 점수',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', '성격유형', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44'],
#       dtype='object')

# %%
df.rename(columns=df.iloc[0])
# Out:
#                    NaN  NaN     NaN  NaN   NaN  NaN  NaN     비율        예상인구수  \
# 0                  NaN  NaN     NaN  NaN   NaN  NaN  NaN     비율        예상인구수
# 1    p_of_sa_m_10_0001  off   10~19   of  10.0   남성    A  0.253   612255.699
# 2    p_of_sa_m_10_0002  off   10~19   of  10.0   남성    B  0.185   447696.855
# 3    p_of_sa_m_10_0003  off   10~19   of  10.0   남성    C  0.232   561436.056
# 4    p_of_sa_m_10_0004  off   10~19   of  10.0   남성    D  0.159   384777.297
# ..                 ...  ...     ...  ...   ...  ...  ...    ...          ...
# 117  p_on_sa_m_60_0004   on  60대 이상   on  60.0   남성    D  0.296  1604190.056
# 118  p_on_sa_w_60_0001   on  60대 이상   on  60.0   여성    A  0.223  1467599.572
# 119  p_on_sa_w_60_0002   on  60대 이상   on  60.0   여성    B  0.284  1869050.576
# 120  p_on_sa_w_60_0003   on  60대 이상   on  60.0   여성    C  0.256  1684777.984
# 121  p_on_sa_w_60_0004   on  60대 이상   on  60.0   여성    D  0.237  1559735.868
#
#       비율  ... NaN  내향/외향  감각/직관  사고/감정  판단/인식          키워드  NaN  NaN  NaN  NaN
# 0     비율  ... NaN  내향/외향  감각/직관  사고/감정  판단/인식          키워드  NaN  NaN  NaN  NaN
# 1      1  ... NaN    0.8    4.2    3.2    3.4  내향적이며, 직관적인    I    N    F    P
# 2    NaN  ... NaN    3.6    1.4    4.8      2  감각적이며, 감정적인    E    S    F    j
# 3    NaN  ... NaN    1.8      3    3.8      3  내향적이며, 감정적인    I    n    F    p
# 4    NaN  ... NaN    3.5    0.8      4    1.6  감각적이며, 판단적인    E    S    F    J
# ..   ...  ...  ..    ...    ...    ...    ...          ...  ...  ...  ...  ...
# 117  NaN  ... NaN      3    3.2      3    3.2  직관적이며, 감정적인    e    N    f    P
# 118    1  ... NaN    2.9    3.1    3.3      3  감정적이며, 인식적인    e    N    F    p
# 119  NaN  ... NaN    2.8    3.1      3      2  내향적이며, 판단적인    e    N    f    j
# 120  NaN  ... NaN    3.2    2.9    4.2    3.7  감정적이며, 인식적인    E    n    F    P
# 121  NaN  ... NaN    3.3      2      2    2.1  감각적이며, 사고적인    E    s    t    j
#
# [122 rows x 45 columns]

# %%
df = df.rename(columns=df.iloc[0]).iloc[1:,:]ㅠ

# %%
df.columns
# Out:
# Index([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,       ' 비율',     '예상인구수',        '비율',
#               '샘플',      '표본오차',      '신뢰수준', '모집단(인구통계)',         nan,
#         '트랜드\n민감도',   '소비\n적극성',  '가격 \n민감도',   '품질\n민감도',   '소비\n충동성',
#                nan,         nan, '상품/서비스 품질',    '브랜드 파워',    '소비자 응대',
#           '광고와 홍보',     '이용편의성',         nan,         nan,    '소비 적극성',
#           '소비 충동성',    '광고와 홍보',     '유형 순위',     '소비력점수',         nan,
#                nan,     '내향/외향',     '감각/직관',     '사고/감정',     '판단/인식',
#              '키워드',         nan,         nan,         nan,         nan],
#       dtype='object')

# %%
df1 = pd.read_excel('sheet2.xlsx')

# %%
df1 = df1.drop_duplicates(subset = ['persona_no'])

# %%
df1 = df1.reset_index()

# %%
df =df.reset_index()

# %%
data = pd.concat([df1,df],axis = 1)

# %%
data
# Out:
#      index industry_code         persona_no active_type age_gender  소비적극성  \
# 0        0       F010101  p_of_sa_m_10_0001          of      10대남성    1.7
# 1        1       F010101  p_of_sa_m_10_0002          of      10대남성    2.3
# 2        2       F010101  p_of_sa_m_10_0003          of      10대남성    2.2
# 3        3       F010101  p_of_sa_m_10_0004          of      10대남성    2.0
# 4        4       F010101  p_of_sa_m_10_0005          of      10대남성    2.0
# ..     ...           ...                ...         ...        ...    ...
# 116  71936       N010101  p_on_sa_w_50_0005          on      50대여성    2.5
# 117  71937       N010101  p_on_sa_w_60_0001          on      60대여성    2.0
# 118  71938       N010101  p_on_sa_w_60_0002          on      60대여성    2.6
# 119  71939       N010101  p_on_sa_w_60_0003          on      60대여성    2.0
# 120  71940       N010101  p_on_sa_w_60_0004          on      60대여성    2.5
#
#      소비충동성  광고와홍보  유형순위  소비력지수  ... NaN  내향/외향  감각/직관  사고/감정  판단/인식  \
# 0      1.9    1.5   1.0    6.1  ... NaN    0.8    4.2    3.2    3.4
# 1      2.4    2.5   0.6    7.8  ... NaN    3.6    1.4    4.8      2
# 2      2.5    2.4   0.8    7.9  ... NaN    1.8      3    3.8      3
# 3      2.2    2.3   0.3    7.1  ... NaN    3.5    0.8      4    1.6
# 4      1.9    2.3   0.6    6.8  ... NaN    1.2      3    3.8    2.8
# ..     ...    ...   ...    ...  ...  ..    ...    ...    ...    ...
# 116    1.6    2.1   0.6    6.7  ... NaN      3    3.2      3    3.2
# 117    2.2    2.3   0.6    7.1  ... NaN    2.9    3.1    3.3      3
# 118    1.3    2.0   1.0    7.0  ... NaN    2.8    3.1      3      2
# 119    2.2    1.9   0.8    6.9  ... NaN    3.2    2.9    4.2    3.7
# 120    2.6    2.8   0.6    8.5  ... NaN    3.3      2      2    2.1
#
#              키워드 NaN NaN NaN NaN
# 0    내향적이며, 직관적인   I   N   F   P
# 1    감각적이며, 감정적인   E   S   F   j
# 2    내향적이며, 감정적인   I   n   F   p
# 3    감각적이며, 판단적인   E   S   F   J
# 4    내향적이며, 감정적인   I   n   F   p
# ..           ...  ..  ..  ..  ..
# 116  직관적이며, 감정적인   e   N   f   P
# 117  감정적이며, 인식적인   e   N   F   p
# 118  내향적이며, 판단적인   e   N   f   j
# 119  감정적이며, 인식적인   E   n   F   P
# 120  감각적이며, 사고적인   E   s   t   j
#
# [121 rows x 62 columns]

# %%
data.fillna(1)
# Out:
#      index industry_code         persona_no active_type age_gender  소비적극성  \
# 0        0       F010101  p_of_sa_m_10_0001          of      10대남성    1.7
# 1        1       F010101  p_of_sa_m_10_0002          of      10대남성    2.3
# 2        2       F010101  p_of_sa_m_10_0003          of      10대남성    2.2
# 3        3       F010101  p_of_sa_m_10_0004          of      10대남성    2.0
# 4        4       F010101  p_of_sa_m_10_0005          of      10대남성    2.0
# ..     ...           ...                ...         ...        ...    ...
# 116  71936       N010101  p_on_sa_w_50_0005          on      50대여성    2.5
# 117  71937       N010101  p_on_sa_w_60_0001          on      60대여성    2.0
# 118  71938       N010101  p_on_sa_w_60_0002          on      60대여성    2.6
# 119  71939       N010101  p_on_sa_w_60_0003          on      60대여성    2.0
# 120  71940       N010101  p_on_sa_w_60_0004          on      60대여성    2.5
#
#      소비충동성  광고와홍보  유형순위  소비력지수  ...  NaN  내향/외향  감각/직관  사고/감정  판단/인식  \
# 0      1.9    1.5   1.0    6.1  ...  1.0    0.8    4.2    3.2    3.4
# 1      2.4    2.5   0.6    7.8  ...  1.0    3.6    1.4    4.8    2.0
# 2      2.5    2.4   0.8    7.9  ...  1.0    1.8    3.0    3.8    3.0
# 3      2.2    2.3   0.3    7.1  ...  1.0    3.5    0.8    4.0    1.6
# 4      1.9    2.3   0.6    6.8  ...  1.0    1.2    3.0    3.8    2.8
# ..     ...    ...   ...    ...  ...  ...    ...    ...    ...    ...
# 116    1.6    2.1   0.6    6.7  ...  1.0    3.0    3.2    3.0    3.2
# 117    2.2    2.3   0.6    7.1  ...  1.0    2.9    3.1    3.3    3.0
# 118    1.3    2.0   1.0    7.0  ...  1.0    2.8    3.1    3.0    2.0
# 119    2.2    1.9   0.8    6.9  ...  1.0    3.2    2.9    4.2    3.7
# 120    2.6    2.8   0.6    8.5  ...  1.0    3.3    2.0    2.0    2.1
#
#              키워드 NaN NaN NaN NaN
# 0    내향적이며, 직관적인   I   N   F   P
# 1    감각적이며, 감정적인   E   S   F   j
# 2    내향적이며, 감정적인   I   n   F   p
# 3    감각적이며, 판단적인   E   S   F   J
# 4    내향적이며, 감정적인   I   n   F   p
# ..           ...  ..  ..  ..  ..
# 116  직관적이며, 감정적인   e   N   f   P
# 117  감정적이며, 인식적인   e   N   F   p
# 118  내향적이며, 판단적인   e   N   f   j
# 119  감정적이며, 인식적인   E   n   F   P
# 120  감각적이며, 사고적인   E   s   t   j
#
# [121 rows x 62 columns]

# %%
float(data['age_gender'][:2])
# Out:
# 10.0

# %%
pd.DataFrame(data['이용편의성'].iloc[:,0]).sort_values(by = '이용편의성',ascending = False).iloc[:3].index
# Out:
# Int64Index([110, 48, 102], dtype='int64')

# %%
for i in range(data.shape[0]):
    data.iloc[i,:]
    break

# %%
int(data.iloc[0]['age_gender'][:2])
# Out:
# 10

# %%
data['persona_no']
# Out:
# 0      p_of_sa_m_10_0001
# 1      p_of_sa_m_10_0002
# 2      p_of_sa_m_10_0003
# 3      p_of_sa_m_10_0004
# 4      p_of_sa_m_10_0005
#              ...
# 116    p_on_sa_w_50_0005
# 117    p_on_sa_w_60_0001
# 118    p_on_sa_w_60_0002
# 119    p_on_sa_w_60_0003
# 120    p_on_sa_w_60_0004
# Name: persona_no, Length: 121, dtype: object

# %%
data
# Out:
#      index industry_code         persona_no active_type age_gender  소비적극성  \
# 0        0       F010101  p_of_sa_m_10_0001          of      10대남성    1.7
# 1        1       F010101  p_of_sa_m_10_0002          of      10대남성    2.3
# 2        2       F010101  p_of_sa_m_10_0003          of      10대남성    2.2
# 3        3       F010101  p_of_sa_m_10_0004          of      10대남성    2.0
# 4        4       F010101  p_of_sa_m_10_0005          of      10대남성    2.0
# ..     ...           ...                ...         ...        ...    ...
# 116  71936       N010101  p_on_sa_w_50_0005          on      50대여성    2.5
# 117  71937       N010101  p_on_sa_w_60_0001          on      60대여성    2.0
# 118  71938       N010101  p_on_sa_w_60_0002          on      60대여성    2.6
# 119  71939       N010101  p_on_sa_w_60_0003          on      60대여성    2.0
# 120  71940       N010101  p_on_sa_w_60_0004          on      60대여성    2.5
#
#      소비충동성  광고와홍보  유형순위  소비력지수  ... NaN  내향/외향  감각/직관  사고/감정  판단/인식  \
# 0      1.9    1.5   1.0    6.1  ... NaN    0.8    4.2    3.2    3.4
# 1      2.4    2.5   0.6    7.8  ... NaN    3.6    1.4    4.8      2
# 2      2.5    2.4   0.8    7.9  ... NaN    1.8      3    3.8      3
# 3      2.2    2.3   0.3    7.1  ... NaN    3.5    0.8      4    1.6
# 4      1.9    2.3   0.6    6.8  ... NaN    1.2      3    3.8    2.8
# ..     ...    ...   ...    ...  ...  ..    ...    ...    ...    ...
# 116    1.6    2.1   0.6    6.7  ... NaN      3    3.2      3    3.2
# 117    2.2    2.3   0.6    7.1  ... NaN    2.9    3.1    3.3      3
# 118    1.3    2.0   1.0    7.0  ... NaN    2.8    3.1      3      2
# 119    2.2    1.9   0.8    6.9  ... NaN    3.2    2.9    4.2    3.7
# 120    2.6    2.8   0.6    8.5  ... NaN    3.3      2      2    2.1
#
#              키워드 NaN NaN NaN NaN
# 0    내향적이며, 직관적인   I   N   F   P
# 1    감각적이며, 감정적인   E   S   F   j
# 2    내향적이며, 감정적인   I   n   F   p
# 3    감각적이며, 판단적인   E   S   F   J
# 4    내향적이며, 감정적인   I   n   F   p
# ..           ...  ..  ..  ..  ..
# 116  직관적이며, 감정적인   e   N   f   P
# 117  감정적이며, 인식적인   e   N   F   p
# 118  내향적이며, 판단적인   e   N   f   j
# 119  감정적이며, 인식적인   E   n   F   P
# 120  감각적이며, 사고적인   E   s   t   j
#
# [121 rows x 62 columns]
